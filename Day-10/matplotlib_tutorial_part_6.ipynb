# %% [markdown]
# # Matplotlib Tutorial
# **Sources:**
# Corey Schafer [Matplotlib Tutorial](https://www.youtube.com/playlist?list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_) Playlist
#
# - Part 6: Histograms

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
rcParams["figure.dpi"] = 100
plt.style.use("ggplot")

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [10, 20, 30, 40, 50, 60]

# %% [markdown]
# ## Use `plt.hist()` to create a histogram
# - We need to pass data for x-axis
# - And bins (range)
# like, 2 people comes in age group of 10-20
# - add parameter `edgecolor` to pass a color of edge for each bin

# %%
plt.title("Ages of People")
plt.xlabel("Ages")
plt.ylabel("No. of people")
plt.hist(ages, bins=bins, edgecolor="black")
plt.tight_layout()

# %% [markdown]
# ### Plotting a histogram on Age of developers

# %%
data = pd.read_csv("./data/age_data.csv")
data.head()
# Out:
#    Id  Age
# 0   1   14
# 1   2   19
# 2   3   28
# 3   4   22
# 4   5   30

# %%
ids = data["Id"]
ages = data.Age

# %%
plt.title("Age of developers")
plt.xlabel("Ages")
plt.ylabel("No. of developers")
bins = [i for i in range(10, 106, 5)]
plt.hist(ages, bins=bins, edgecolor="black", label="Age")
plt.legend()

# %% [markdown]
# #### We can convert the y-axis to a logarithm scale, so that values are in log

# %%
plt.title("Age of developers")
plt.xlabel("Ages")
plt.ylabel("No. of developers")
plt.hist(ages, bins=bins, edgecolor="black", label="Age", log=True)
plt.legend()

# %% [markdown]
# ### To add a vertical line in the histogram, use `plt.axvline()` and pass the `x` axis point, where to make the line

# %%
median_age = data["Age"].median()
plt.title("Age of developers")
plt.xlabel("Ages")
plt.ylabel("No. of developers")
plt.hist(ages, bins=bins, edgecolor="black", label="Age", log=True)
# axis vertical line
plt.axvline(median_age, color="#0000FF", label="Age Median")
plt.legend()
